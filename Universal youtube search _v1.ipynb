# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
from youtube_data import youtube_search
from ipywidgets import widgets

# %%
youtube_name = input("What is the keyword of the youtube?")
test = youtube_search(youtube_name)
test.keys()
# Out:
# What is the keyword of the youtube?angular 6
# dict_keys(['tags', 'channelId', 'channelTitle', 'categoryId', 'title', 'videoId', 'viewCount', 'likeCount', 'dislikeCount', 'commentCount', 'favoriteCount'])

# %%
test['commentCount'][:5]
# Out:
# ['391', '173', '40', '131', '80']

# %%
df = pd.DataFrame(data=test)
df.head()
# Out:
#   categoryId                 channelId              channelTitle commentCount  \
# 0         26  UCVyRiMvfUNMA1UPlDPzG5Ow              DesignCourse          391
# 1         28  UCSJbGtTlrDami-tDGPUV9-w                 Academind          173
# 2         27  UC80PWRj_ZU8Zu0HSMNVwKWw              Codevolution           40
# 3         28  UC29ju8bIPH5as8OGnQzwJyA            Traversy Media          131
# 4         28  UCnUYZLuoy1rq1aVMwx4aTzw  Google Chrome Developers           80
#
#   dislikeCount favoriteCount likeCount  \
# 0           41             0      2639
# 1           17             0       794
# 2            4             0       398
# 3           15             0       798
# 4           54             0      1397
#
#                                                 tags  \
# 0  [angular, angular 6, angular 6 tutorial, angul...
# 1  [angular, angular.js, angular2, angular 6, ang...
# 2  [Angular, Angular Tutorial for Beginners, Angu...
# 3  [angular 6, angular 6 features, angular 6 rele...
# 4  [Angular, new in Angular, Angular bundles, mob...
#
#                                                title      videoId viewCount
# 0  Learn Angular 6 in 60 Minutes - Free Beginners...  z4JUm0Bq9AM    105591
# 1  Angular 6 Upgrade - Breaking Changes & Feature...  Xr5l7lT--YU     40566
# 2  Angular 6 Tutorial - 30 - Angular 6 New Featur...  RkV_LozGP3w     30068
# 3                         Angular 6 - What To Expect  XW7_jhrUNmM     25094
# 4             What's new in Angular (Google I/O '18)  jnp_ny4SOQE    103999

# %%
df1 = df[['title','viewCount','channelTitle','commentCount','likeCount','dislikeCount','tags','favoriteCount','videoId','channelId','categoryId']]
df1.columns = ['Title','viewCount','channelTitle','commentCount','likeCount','dislikeCount','tags','favoriteCount','videoId','channelId','categoryId']
df1.head()
# Out:
#                                                Title viewCount  \
# 0  Learn Angular 6 in 60 Minutes - Free Beginners...    105591
# 1  Angular 6 Upgrade - Breaking Changes & Feature...     40566
# 2  Angular 6 Tutorial - 30 - Angular 6 New Featur...     30068
# 3                         Angular 6 - What To Expect     25094
# 4             What's new in Angular (Google I/O '18)    103999
#
#                channelTitle commentCount likeCount dislikeCount  \
# 0              DesignCourse          391      2639           41
# 1                 Academind          173       794           17
# 2              Codevolution           40       398            4
# 3            Traversy Media          131       798           15
# 4  Google Chrome Developers           80      1397           54
#
#                                                 tags favoriteCount  \
# 0  [angular, angular 6, angular 6 tutorial, angul...             0
# 1  [angular, angular.js, angular2, angular 6, ang...             0
# 2  [Angular, Angular Tutorial for Beginners, Angu...             0
# 3  [angular 6, angular 6 features, angular 6 rele...             0
# 4  [Angular, new in Angular, Angular bundles, mob...             0
#
#        videoId                 channelId categoryId
# 0  z4JUm0Bq9AM  UCVyRiMvfUNMA1UPlDPzG5Ow         26
# 1  Xr5l7lT--YU  UCSJbGtTlrDami-tDGPUV9-w         28
# 2  RkV_LozGP3w  UC80PWRj_ZU8Zu0HSMNVwKWw         27
# 3  XW7_jhrUNmM  UC29ju8bIPH5as8OGnQzwJyA         28
# 4  jnp_ny4SOQE  UCnUYZLuoy1rq1aVMwx4aTzw         28

# %%
youtube_channel = input("What channel do you want to search?")
mask = df1["channelTitle"] == youtube_channel
df1[mask]
# Out:
# What channel do you want to search?
# Empty DataFrame
# Columns: [Title, viewCount, channelTitle, commentCount, likeCount, dislikeCount, tags, favoriteCount, videoId, channelId, categoryId]
# Index: []

# %%
import numpy as np
numeric_dtype = ['viewCount','commentCount','likeCount','dislikeCount','favoriteCount']
for i in numeric_dtype:
    df1[i] = df[i].astype(int)

# %%
df1 = df1.sort_values(ascending=False,by='viewCount')
plt.bar(range(df1.shape[0]),df1['viewCount'])
plt.xticks(range(df1.shape[0]),df1['Title'],rotation=90)
plt.ylabel('viewCount in 100 millions')

plt.show()

# %%
df1 = df1.sort_values(ascending=False,by='viewCount')
plt.bar(range(df1.shape[0]),df1['commentCount'])
plt.xticks(range(df1.shape[0]),df1['Title'],rotation=90)
plt.ylabel('commentCount in 100 millions')

plt.show()
